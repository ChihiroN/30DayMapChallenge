# %% [markdown]
# <a href="https://colab.research.google.com/github/ChihiroN/30DayMapChallenge/blob/main/00_rapid_start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.datasets import mnist

# %% [markdown]
# ####

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train.ndim
# Out:
# 3

# %% [markdown]
# ####

# %%
data=pd.DataFrame({
    "col1":[1,2,None,np.nan],
    "col2":[1.2,2.3,None,np.nan],
    "col3":['aaa','bbb',None,np.nan]
})
data
# Out:
#    col1  col2  col3
# 0   1.0   1.2   aaa
# 1   2.0   2.3   bbb
# 2   NaN   NaN  None
# 3   NaN   NaN   NaN

# %%
data.isna()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2   True   True   True
# 3   True   True   True

# %%
data.dropna()
# Out:
#    col1  col2 col3
# 0   1.0   1.2  aaa
# 1   2.0   2.3  bbb

# %%
s=pd.Series([3,2,3,2,2])
s2=pd.Series([2,4,6,8,10])

# %%
s
# Out:
# 0    3
# 1    2
# 2    3
# 3    2
# 4    2
# dtype: int64

# %%
s2
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
df=pd.concat([s,s2],axis=1)
df
# Out:
#    0   1
# 0  3   2
# 1  2   4
# 2  3   6
# 3  2   8
# 4  2  10

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### q.33

# %%
from sklearn.model_selection import train_test_split as tts

# %%
def f(x):
  return np.sin(2*np.pi*x)
sin_x=np.linspace(0,1,100)
x=np.random.rand(100)[:,np.newaxis]
y=f(x)+np.random.rand(100)[:,np.newaxis]-0.5
x_train,x_test,y_train,y_test=tts(x,y)

# %%
plt.plot(sin_x,f(sin_x),':')

# %%
plt.scatter(x_train,y_train)

# %% [markdown]
# #### q.35

# %%
import seaborn as sns
iris=sns.load_dataset("iris")
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.jointplot(x=df["sepal_length"], y=df["sepal_width"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-478fb11b04b1> in <cell line: 1>()
# ----> 1 sns.jointplot(x=df["sepal_length"], y=df["sepal_width"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     347                 raise KeyError(key) from err
#     348         if isinstance(key, Hashable):
# --> 349             raise KeyError(key)
#     350         self._check_indexing_error(key)
#     351         raise KeyError(key)
#
# KeyError: 'sepal_length'

# %% [markdown]
# #### q.36

# %%
from sklearn import datasets
from sklearn import svm

# %%
digits=datasets.load_digits()
dataset=digits.data
target=digits.target
train_dataset=dataset[:-10]
train_target=target[:-10]
test_dataset=dataset[-10:]
test_target=target[-10:]

# %%
clf=svm.SVC(gamma=0.001,C=100)

# %%
clf.fit(train_dataset,train_target)
# Out:
# SVC(C=100, gamma=0.001)

# %%
clf.predict(test_dataset)
# Out:
# array([5, 4, 8, 8, 4, 9, 0, 8, 9, 8])

# %% [markdown]
# #### q.38

# %%
from sklearn import datasets,linear_model

# %%
iris=datasets.load_iris()
x=iris.data[:,0]
y=iris.data[:,2]
model=linear_model.LinearRegression()
model.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x,model.predict(x.reshape(-1,1)))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
